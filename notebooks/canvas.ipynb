# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
import numpy as np
import matplotlib.pyplot as plt

from scene.canvas import Scene
from objects.common import Square, Rectangle
from objects.particles import Particles

# %%
# %load_ext autoreload

# %%
scene = Scene(id='world', width=200, height=100)
scene.add_rectangle(id='box', center=[0,0], width=100, height=50, color='k')
scene.add_particles(
  id='He',
  n_particles=3,
  mass=5,
  radius=3,
  vlim=[0, 5],
  parent_object_id='box'
)
scene.add_particles(
  id='H',
  n_particles=5,
  mass=5,
  radius=3,
  vlim=[0, 5],
  parent_object_id='box',
  color='green'
)
scene.render_frame()
